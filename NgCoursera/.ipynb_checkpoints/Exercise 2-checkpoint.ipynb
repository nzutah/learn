# %%
import pandas
import statsmodels.api as sm
from numpy import dot, log, ones, zeros, exp, asarray, linspace, ones_like
from scipy.optimize import fmin_cg
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import theme
theme.load_style()
# Out:
# <style>
# @import url('http://fonts.googleapis.com/css?family=Source+Code+Pro');
# @import url('http://fonts.googleapis.com/css?family=Vollkorn');
# @import url('http://fonts.googleapis.com/css?family=Arimo');
# @import url('http://fonts.googleapis.com/css?family=Arvo:400,700,400italic')
#
# #notebook li { /* More space between bullet points */
#     margin-top:0.8em;
# }
#
# /* draw border around running cells */
# div.cell.border-box-sizing.code_cell.running {
#     border: 3px solid #111;
# }
#
# div.cell.code_cell {
#     margin-top: 1em;
#     margin-left: auto;
#     margin-right: auto;
#     width: 800px;
#     border: 1px solid rgba(200, 200, 200, 0.8);
#     border-radius: 8px; /* rounded borders */
# }
#
# div.text_cell_render{
#     font-family: 'Arvo' sans-serif;
#     /* font-family: 'Arimo',verdana,arial,sans-serif; */
#     line-height: 130%;
#     font-size: 115%;
#     margin-left:0%;
#     margin-right:auto;
# }
#
# .text_cell_render h1 {
#     font-family: 'Open sans',verdana,arial,sans-serif;
#     font-weight: 300;
#     font-style: bold;
#     font-size: 30pt;
#     line-height: 100%;
#     color:#c76c0c;
#     margin-top: 0.75em;
#     margin-bottom: 0.05em;
#     display: block;
# }
#
# .text_cell_render h2 {
#     font-family: 'Open sans',verdana,arial,sans-serif;
#     font-weight: 200;
#     font-size: 20pt;
#     line-height: 100%;
#     color:#c76c0c;
#     margin-top: 0.75em;
#     margin-bottom: 0.05em;
#     display: block;
# }
#
# .text_cell_render h3 {
#     font-family: 'Open sans',verdana,arial,sans-serif;
#     font-weight: 200;
#     font-size: 16pt;
#     line-height: 100%;
#     color:#d77c0c;
#     margin-top: 0.75em;
#     margin-bottom: 0.05em;
#     display: block;
# }
#
# .text_cell_render h4 {
#     font-family: 'Open sans',verdana,arial,sans-serif;
#     font-weight: 200;
#     font-size: 14pt;
#     font-style: italic;
#     line-height: 100%;
#     color:#d77c0c;
#     margin-top: 0.75em;
#     margin-bottom: 0.05em;
#     display: block;
# }
#
# .text_cell_render h5 {
#     font-family: 'Open sans',verdana,arial,sans-serif;
#     font-weight: 200;
#     font-size: 12pt;
#     color: #1d3b84;
#     margin-top: 0.75em;
#     margin-bottom: 0.05em;
# }
#
# .rendered_html code{
#     background-color: transparent;
# }
#
# ul{
#     margin: 2em;
# }
#
# ul li{
#     padding-left: 0.5em;
#     margin-bottom: 0.5em;
#     margin-top: 0.5em;
# }
#
# ul li li{
#     padding-left: 0.2em;
#     margin-bottom: 0.2em;
#     margin-top: 0.2em;
# }
#
# ol{
#     margin: 2em;
# }
#
# ol li{
#     padding-left: 0.5em;
#     margin-bottom: 0.5em;
#     margin-top: 0.5em;
# }
#
# ul li{
#     padding-left: 0.5em;
#     margin-bottom: 0.5em;
#     margin-top: 0.2em;
# }
#
# a:link{
#     font-weight: bold;
#     color:#447adb;
# }
#
# a:visited{
#     font-weight: bold;
#     color: #1d3b84;
# }
#
# a:hover{
#     font-weight: bold;
#     color: #1d3b84;
# }
#
# a:focus{
#     font-weight: bold;
#     color:#447adb;
# }
#
# a:active{
#     font-weight: bold;
#     color:#447adb;
# }
#
# .rendered_html :link {
#     text-decoration: underline;
# }
#
# .rendered_html :hover {
#     text-decoration: none;
# }
#
# .rendered_html :visited {
#     text-decoration: none;
# }
#
# .rendered_html :focus {
#     text-decoration: none;
# }
#
# .rendered_html :active {
#     text-decoration: none;
# }
#
# .warning{
#     color: rgb( 240, 20, 20 )
# }
#
# hr {
#     color: #f3f3f3;
#     background-color: #f3f3f3;
#     height: 1px;
# }
#
# blockquote{
#     display:block;
#     background: #fcfcfc;
#     border-left: 5px solid #c76c0c;
#     font-family: 'Open sans',verdana,arial,sans-serif;
#     width:680px;
#     padding: 10px 10px 10px 10px;
# }
#
# blockquote p {
#     margin-bottom: 0;
#     line-height: 125%;
#     font-size: 100%;
# }
#
# table#mytable,
# table#mytable td,
# table#mytable tr
# {
#     border: none !important;
# }
#
# table#mytable-1,
# table#mytable-1 td,
# table#mytable-1 tr
# {
#     border: none !important;
#     align: center;
#     cellspacing: 10;
# }
#
# .msg {
#     width: 90%;
#     margin-left: auto;
#     margin-right: auto;
#     margin-top: 10px;
#     margin-bottom: 10px;
#     padding: 14px 14px 14px 14px;
#     color: #c09853;
#     text-shadow: 0 1px 0 rgba(255, 255, 255, 0.5);
#     background-color: #fcf8e3;
#     border: 1px solid #fbeed5;
#     -webkit-border-radius: 4px;
#     -moz-border-radius: 4px;
#     border-radius: 4px;
# }
#
# .msg-heading {
#     color: inherit;
# }
#
# .msg .close {
#     position: relative;
#     top: -2px;
#     right: -21px;
#     line-height: 18px;
# }
#
# .msg-success {
#     color: #468847;
#     background-color: #dff0d8;
#     border-color: #d6e9c6;
# }
#
# .msg-danger,
# .msg-error {
#     color: #b94a48;
#     background-color: #f2dede;
#     border-color: #eed3d7;
# }
#
# .msg-info {
#     color: #3a87ad;
#     background-color: #d9edf7;
#     border-color: #bce8f1;
# }
#
# .boxed {
#     color: #b94a48;
#     background-color: #f2dede;
#     border-color: #eed3d7;
#     margin-left: auto;
#     margin-right: auto;
#     padding: 14px 14px 14px 14px;
# }
#
# .w-300 { width: 300px; }
# .w-400 { width: 400px; }
# .w-500 { width: 500px; }
#
# </style>

# %% [markdown]
# # Exercise 2: Logistic Regression

# %% [markdown]
# ## 1. Logistic Regression

# %%
data = pandas.read_csv('data/ex2data1.txt', header=None,
                       names=('Test 1', 'Test 2', 'Admit'))
# Add the intercept
data.insert(0, 'Intercept', 1.)
nfeatures = data.shape[1] - 1

# %% [markdown]
# ### 1.1 Visualizing Data

# %% [markdown]
# #### 1.1.1 Data Description

# %%
data.describe()
# Out:
#        Intercept      Test 1      Test 2       Admit
# count        100  100.000000  100.000000  100.000000
# mean           1   65.644274   66.221998    0.600000
# std            0   19.458222   18.582783    0.492366
# min            1   30.058822   30.603263    0.000000
# 25%            1   50.919511   48.179205    0.000000
# 50%            1   67.032988   67.682381    1.000000
# 75%            1   80.212529   79.360605    1.000000
# max            1   99.827858   98.869436    1.000000

# %% [markdown]
# #### 1.1.2 Dot Plots

# %%
admitted = data.loc[data['Admit'] == 1]
not_admitted = data.loc[data['Admit'] == 0]

plot(admitted['Test 1'], admitted['Test 2'], 'k+', 
     label='Admitted')
plot(not_admitted['Test 1'], not_admitted['Test 2'], 'yo', 
     label='Not Admitted')
legend();

# %% [markdown]
# #### 1.1.3 Histogram

# %%
data.hist();

# %% [markdown]
# ### 1.2 Implementation
#
# #### 1.2.1 Sigmoid Function

# %%
def sigmoid(z):
    return 1. / (1. + exp(-z))

# %% [markdown]
# #### 1.2.2 Cost Function

# %%
def costfun(theta, x, y, lam=None):
    # the cost function
    x, y = asarray(x), asarray(y)
    z = dot(x, theta)
    ht = sigmoid(z)
    m, n = x.shape
    ht[where(ht >= 1.)] = .99
    J = (-dot(y, log(ht)) - dot((1 - y), log(1 - ht))) / m
    if lam is not None:
        J += lam / 2. / m * dot(theta[1:], theta[1:])
    return J

def costfun_grad(theta, x, y, lam=None):
    # the cost function gradient
    x, y = asarray(x), asarray(y)
    z = dot(x, theta)
    ht = sigmoid(z)
    m, n = x.shape
    grad = dot(x.T, ht - y) / m
    if lam is not None:
        grad[1:] += lam / m * theta[1:]
    return grad

def predict(theta, x):
    return round(sigmoid(dot(x, theta)))
    
theta = zeros(nfeatures)
J = costfun(theta, data.drop('Admit', axis=1), data['Admit'])
assert abs(J - .693) < 5.e-4

# %% [markdown]
# #### 1.2.3 Learning Parameters

# %%
theta = fmin_cg(costfun, theta, disp=0,
                args=(data.drop('Admit', axis=1), data['Admit']),
                fprime=costfun_grad)
J = costfun(theta, data.drop('Admit', axis=1), data['Admit'])
assert abs(J - .203) < 5e-3

# %%
plot(admitted['Test 1'], admitted['Test 2'], 'k+', 
     label='Admitted')
plot(not_admitted['Test 1'], not_admitted['Test 2'], 'yo', 
     label='Not Admitted')

# Only need 2 points to define a line, so choose two endpoints
xp = array([min(data['Test 1']),  max(data['Test 1'])])

# Calculate the decision boundary line
yp = (-1. / theta[2]) * (theta[1] * xp + theta[0])

# plot the decision boundary
plot(xp, yp)
xlim(30, 100)
ylim(30, 100)
legend();

# %% [markdown]
# #### 1.2.4 Evaluating Logistic Expression

# %%
assert abs(sigmoid(dot(theta, [1, 45, 85])) - .776) < 5e-3

# %%
def warn(message, *args):
    message = message % args
    print '*** warning: %s' % message
for (i, row) in data.iterrows():
    prediction = predict(theta, [1, row['Test 1'], row['Test 2']])
    if prediction != row['Admit']:
        T1, T2 = row['Test 1'], row['Test 2']
        warn('incorrect prediction for '
             'Test 1 = %.2f, Test 2 = %.2f, ', T1, T2)
# Out:
# *** warning: incorrect prediction for Test 1 = 75.02, Test 2 = 46.55,
# *** warning: incorrect prediction for Test 1 = 95.86, Test 2 = 38.23,
# *** warning: incorrect prediction for Test 1 = 69.07, Test 2 = 52.74,
# *** warning: incorrect prediction for Test 1 = 93.11, Test 2 = 38.80,
# *** warning: incorrect prediction for Test 1 = 52.05, Test 2 = 69.43,
# *** warning: incorrect prediction for Test 1 = 33.92, Test 2 = 98.87,
# *** warning: incorrect prediction for Test 1 = 82.37, Test 2 = 40.62,
# *** warning: incorrect prediction for Test 1 = 32.58, Test 2 = 95.60,
# *** warning: incorrect prediction for Test 1 = 82.23, Test 2 = 42.72,
# *** warning: incorrect prediction for Test 1 = 57.24, Test 2 = 59.51,
# *** warning: incorrect prediction for Test 1 = 55.34, Test 2 = 64.93,

# %% [markdown]
# ## 2. Regularized Logistic Regression

# %% [markdown]
# ### 2.1 Visualizing the Data

# %%
data = pandas.read_csv('data/ex2data2.txt', header=None,
                       names=('Test 1', 'Test 2', 'Admit'))
y1 = data.loc[data['Admit'] == 1]
y0 = data.loc[data['Admit'] == 0]
plot(y1['Test 1'], y1['Test 2'], 'k+', label='y=1')
plot(y0['Test 1'], y0['Test 2'], 'yo', label='y=0')
legend();

# %% [markdown]
# ### 2.2 Feature Mapping

# %%
def map_feature(x1, x2):
    x1 = asarray(x1)
    x2 = asarray(x2)
    data = pandas.DataFrame()

    data['X1'] = x1
    data['X2'] = x2
    degree = 6
    for i in range(1, degree + 1):
        for j in range(i+1):
            key = '{0}{1}'.format(i, j)
            data[key] = x1 ** (i - j) * x2 ** j
            
    # Add the intercept
    data.insert(0, 'Intercept', 1.)
    return data
X = map_feature(data['Test 1'], data['Test 2'])
nfeatures = X.shape[1]

# %% [markdown]
# ### 2.3 Cost Function and Gradient

# %%
theta = zeros(nfeatures)
lam = 1.
J = costfun(theta, X, data['Admit'])
assert abs(J - .693) < 5e-4

# %% [markdown]
# #### 2.3.1 Learning Parameters

# %%
theta = fmin_cg(costfun, theta, disp=0, args=(X, data['Admit'], lam),
                fprime=costfun_grad)
J = costfun(theta, X, data['Admit'])

# %% [markdown]
# ### 2.4 Plotting the Decision Boundary

# %%
# The grid range
n = 50
u = linspace(-1, 1.5, n)
v = linspace(-1, 1.5, n)

z = zeros((n, n))
# Evaluate z = theta.x over the grid
for i in range(n):
    for j in range(n):
        z[i,j] = dot(map_feature(u[i:i+1], v[j:j+1]), theta)

y1 = data.loc[data['Admit'] == 1]
y0 = data.loc[data['Admit'] == 0]
plot(y1['Test 1'], y1['Test 2'], 'k+', label='y=1')
plot(y0['Test 1'], y0['Test 2'], 'yo', label='y=0')

# Plot z = 0
# Notice you need to specify the range [0, 0]
contour(u, v, z, [0, 0], label='Decision Boundary')

legend();

# %% [markdown]
# ## 3. Logistic Expression Using statsmodels

# %%
data = pandas.read_csv('data/ex2data2.txt', header=None,
                       names=('Test 1', 'Test 2', 'Admit'))

# create the new features and merge with data, 
# map_feature creates the intercept
X = map_feature(data['Test 1'], data['Test 2'])

logit = sm.Logit(data['Admit'], X)
fit = logit.fit()    
fit.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.219290
#          Iterations 26
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  Admit   No. Observations:                  118
# Model:                          Logit   Df Residuals:                       90
# Method:                           MLE   Df Model:                           27
# Date:                Sun, 24 May 2015   Pseudo R-squ.:                  0.6836
# Time:                        00:06:01   Log-Likelihood:                -25.876
# converged:                       True   LL-Null:                       -81.774
#                                         LLR p-value:                 2.756e-12
# ==============================================================================
#                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     38.2308     11.259      3.396      0.001        16.163    60.298
# X1            27.7979        nan        nan        nan           nan       nan
# X2            49.0733        nan        nan        nan           nan       nan
# 10            27.7979        nan        nan        nan           nan       nan
# 11            49.0733        nan        nan        nan           nan       nan
# 20          -369.4302    113.570     -3.253      0.001      -592.024  -146.836
# 21          -177.1204     87.554     -2.023      0.043      -348.723    -5.518
# 22          -194.2606     50.295     -3.862      0.000      -292.837   -95.684
# 30          -366.0087    125.475     -2.917      0.004      -611.935  -120.082
# 31          -842.2109    156.854     -5.369      0.000     -1149.640  -534.782
# 32          -719.4483     57.411    -12.532      0.000      -831.972  -606.925
# 33          -511.8946     36.270    -14.113      0.000      -582.983  -440.806
# 40          1182.7018    348.676      3.392      0.001       499.309  1866.095
# 41          1279.3434    444.874      2.876      0.004       407.407  2151.279
# 42          1907.9002    506.088      3.770      0.000       915.986  2899.815
# 43           914.3191    333.705      2.740      0.006       260.270  1568.368
# 44           514.2802        nan        nan        nan           nan       nan
# 50           573.2232    212.471      2.698      0.007       156.789   989.658
# 51          1629.7512    412.349      3.952      0.000       821.561  2437.941
# 52          2553.6041    400.655      6.374      0.000      1768.335  3338.874
# 53          2919.0670        nan        nan        nan           nan       nan
# 54          1780.6083        nan        nan        nan           nan       nan
# 55           785.3151    111.108      7.068      0.000       567.547  1003.083
# 60         -1257.9132    357.359     -3.520      0.000     -1958.324  -557.502
# 61         -2260.0053    643.078     -3.514      0.000     -3520.415  -999.596
# 62         -4142.7960    993.830     -4.169      0.000     -6090.667 -2194.925
# 63         -4290.5928    738.923     -5.807      0.000     -5738.855 -2842.330
# 64         -4229.6513    250.523    -16.883      0.000     -4720.667 -3738.636
# 65         -2055.5485    146.814    -14.001      0.000     -2343.299 -1767.798
# 66          -750.3815        nan        nan        nan           nan       nan
# ==============================================================================
# """

# %%
fit.conf_int()
# Out:
#                      0            1
# Intercept    16.163252    60.298443
# X1                 NaN          NaN
# X2                 NaN          NaN
# 10                 NaN          NaN
# 11                 NaN          NaN
# 20         -592.024150  -146.836236
# 21         -348.723263    -5.517615
# 22         -292.837242   -95.683959
# 30         -611.934985  -120.082373
# 31        -1149.640002  -534.781715
# 32         -831.971515  -606.924995
# 33         -582.982886  -440.806308
# 40          499.308510  1866.095133
# 41          407.407338  2151.279461
# 42          915.985728  2899.814752
# 43          260.269817  1568.368343
# 44                 NaN          NaN
# 50          156.788634   989.657805
# 51          821.561223  2437.941174
# 52         1768.334719  3338.873578
# 53                 NaN          NaN
# 54                 NaN          NaN
# 55          567.547374  1003.082753
# 60        -1958.324161  -557.502158
# 61        -3520.414657  -999.595957
# 62        -6090.667166 -2194.924800
# 63        -5738.855268 -2842.330413
# 64        -4720.666589 -3738.635937
# 65        -2343.299044 -1767.797939
# 66                 NaN          NaN
